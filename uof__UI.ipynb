# %% [markdown]
# <a href="https://colab.research.google.com/github/anjalipatel101/481_Project_Fall_2023/blob/ULTIMATE_OFFICIAL/uof__UI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# !ln -s "/gdrive/MyDrive/481_AI_project/templates" "/content/templates"
# !ln -s "/gdrive/MyDrive/481_AI_project/models" "/content/models"
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# ln: failed to create symbolic link '/content/templates/templates': File exists
# ln: failed to create symbolic link '/content/models/models': File exists

# %%
# Backend/UI imports
# !pip install flask_ngrok
# !pip install pyngrok==4.1.1
# !pip install flask_cors

# %%
# !ngrok authtoken 2ZE5sJ2XtQ8GReACzTzcrLyGrAB_4LPopJEQ8Fs8HdQbyFReV # cardinal sin to have the auth token here but no time
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
# Machine learning imports
import tensorflow as tf
import numpy as np
new_model = tf.keras.models.load_model('/content/models/hisA_model.keras')
# class_names = new_model.class_names

# %%
reverse_mapping = {
  0: {
   "facts": [
      " Strong, athletic dogs with loyalty and affection.",
      " Good with children when trained and socialized.",
      " Responsible ownership and positive reinforcement are crucial."
      ],
    "prediction": "American Pitbull Terrier"
  },
  1: {
    "facts": [
      " Yorkies are small dogs with long, silky fur and a confident attitude.",
      " They're smart and can learn tricks and activities quickly.",
      " Even though they're tiny, they need playtime and mental stimulation to stay happy."
      ],
    "prediction": "Yorkshire Terrier",
  },
  2: {
    "facts": [
      " Cats with striking blue almond-shaped eyes and color-point markings.",
      " Gentle and affectionate nature.",
      " Relatively low-maintenance grooming."
      ],
    "prediction": "Birman",
  },
  3: {
    "facts": [
      " Small, sturdy dogs with a long, silky coat.",
      " Friendly disposition, good with children and other pets.",
      " Regular grooming is essential."
      ],
    "prediction": "Havanese",
  },
  4: {
    "facts": [
      " Large, fluffy dogs with a distinctive \"Sammy smile.\"",
      " Friendly, sociable, and often good with children.",
      " Regular grooming is essential to manage shedding."
      ],
    "prediction": "Samoyed",
  },
  5: {
    "facts": [
      " Cats with a distinctive spotted or marbled coat.",
      " Energetic and playful, may enjoy climbing.",
      " Intelligent cats requiring mental stimulation."
      ],
    "prediction": "Bengal",
  },
  6: {
    "facts": [
      " Small dogs with a compact build, known for their spirited nature.",
      " Display a fearless attitude despite their small size.",
      " Early socialization and training are essential."
      ],
    "prediction": "Miniature Pinscher",
  },
  7: {
    "facts": [
      " Cats known for a long, luxurious coat, flat face, and expressive eyes.",
      " Calm and laid-back personality, prefers a quiet indoor environment.",
      " Regular grooming is essential to prevent matting."
      ],
    "prediction": "Persian",
  },
  8: {
    "facts": [
      " Medium-sized cats with a spotted coat resembling wild leopards.",
      " Active and playful nature, enjoys climbing and interactive play.",
      " May form strong bonds with owners and appreciate mental stimulation."
      ],
    "prediction": "Egyptian Mau",
  },
  9: {
    "facts": [
      " One of the smallest dog breeds, with a bold personality.",
      " Can exhibit a confident attitude despite their size.",
      " Excellent companions for individuals or families in smaller living spaces."
      ],
    "prediction": "Chihuahua",
  },
  10: {
     "facts": [
      " Hairless cats with distinctive large ears and wrinkled skin.",
      " Require regular bathing to remove oils from their skin.",
      " Described as affectionate and enjoying attention."
      ],
    "prediction": "Sphynx",
  },
  11: {
    "facts": [
      " One of the largest domestic cat breeds.",
      " Friendly and sociable, often good with children.",
      " Prized for intelligence and adaptability."
      ],
    "prediction": "Maine Coon",
  },
  12: {
    "facts": [
      " Muscular, athletic dogs known for strength and loyalty.",
      " Friendly and outgoing, often good with children.",
      " Regular exercise and mental stimulation are important."
      ],
    "prediction": "American Bulldog",
  },
  13: {
    "facts": [
      " Recognized for striking blue almond-shaped eyes and color-point coat.",
      " Highly vocal and interactive with owners.",
      " Intelligent cats requiring mental stimulation."
      ],
    "prediction": "Siamese",
  },
  14: {
    "facts": [
      " Versatile hunting dogs with athleticism and intelligence.",
      " Short coat, highly energetic, requiring regular exercise.",
      " Friendly and trainable, excellent family pets."
      ],
    "prediction": "German Shorthaired",
  },
  15: {
    "facts": [
      " Large, majestic dogs with a lion-like mane.",
      " Gentle and friendly temperament, good with children.",
      " Require regular exercise and mental stimulation."
      ],
    "prediction": "Leonberger",
  },
  16: {
    "facts": [
      " Medium-sized cats with a sleek, black coat.",
      " Friendly and affectionate, forming strong bonds.",
      " Often described as \"mini-panthers.\""
      ],
    "prediction": "Bombay",
  },
  17: {
    "facts": [
      " Small dogs with a distinctive wiry coat.",
      " Dignified and independent nature.",
      " Proper training and socialization are essential."
      ],
    "prediction": "Scottish Terrier",
  },
  18: {
    "facts": [
      " Medium-sized dogs with a spectacles appearance.",
      " Friendly and outgoing nature, excellent companions.",
      " Thick double coat requires regular grooming."
      ],
    "prediction": "Keeshond",
  },
  19: {
    "facts": [
      " Compact size, wrinkled face, and curled tail.",
      " Playful and sociable nature, suitable for various households.",
      " Prone to weight gain, sensitive to extreme temperatures."
      ],
    "prediction": "Pug",
  },
  20: {
    "facts": [
      " Medium-sized cats with a short, ticked coat.",
      " Playful and active nature, enjoys climbing.",
      " Social cats that may form strong bonds."
      ],
    "prediction": "Abyssinian",
  },
  21: {
    "facts": [
      " Japanese breed with a fox-like appearance.",
      " Independent nature, forming strong bonds once comfortable.",
      " Strong prey drive, requiring early training and socialization."
      ],
    "prediction": "Shiba Inu",
  },
  22: {
    "facts": [
      " Known for their distinctive, long ears and droopy expression.",
      " Excellent sense of smell, traditionally used in hunting." ,
      " Generally friendly, affectionate, and good with families."
      ],
    "prediction": "Basset Hound",
  },
  23: {
    "facts": [
      " Small, fluffy dogs with a lively and extroverted personality.",
      " Distinctive fox-like face and a luxurious double coat.",
      " Bold and confident, making them good watchdogs."
      ],
    "prediction": "Pomeranian",
  },
  24: {
    "facts": [
      " Medium to large-sized dogs with a silky coat.",
      " Known for a gentle and friendly demeanor.",
      " Moderate energy level, enjoys outdoor activities."
      ],
    "prediction": "English Setter",
  },
  25: {
    "facts": [
      " Medium-sized dogs with a long, silky coat.",
      " Friendly and affectionate, suitable for families.",
      " Regular exercise and mental stimulation needed."
      ],
    "prediction": "English Cocker Spaniel",
  },
  26: {
    "facts": [
      " Recognized for round faces, dense coat, and large eyes.",
      " Calm and easygoing temperament.",
      " Adaptable to various living environments."
      ],
    "prediction": "British Shorthair",
  },
  27: {
    "facts": [
      " Recognized for striking blue-gray coat and vivid green eyes.",
      " Reserved nature, forming strong bonds with owners.",
      " Low-shedding and hypoallergenic."
      ],
    "prediction": "Russian Blue",
  },
  28: {
    "facts": [
      " Cats with striking blue eyes, silky coat, and docile temperament.",
      " Tend to go limp when picked up, known for gentle nature.",
      " Sociable cats that enjoy the company of their owners."
      ],
    "prediction": "Ragdoll",
  },
  29: {
    "facts": [
      " Small to medium-sized with a friendly and curious demeanor.",
      " Keen sense of smell, often used in detection work.",
      " Energetic and requires regular exercise."
      ],
    "prediction": "Beagle",
  },
  30: {
    "facts": [
      " Giant dogs known for a thick, weather-resistant double coat.",
      " Calm and gentle nature, often showing a strong protective instinct.",
      " Regular grooming and consistent training are important."
      ],
    "prediction": "Great Pyrenees",
  },
  31: {
    "facts": [
      " Muscular and agile dogs with loyalty and affection.",
      " Generally good with children and a friendly disposition.",
      " Proper training and socialization are crucial."
      ],
    "prediction": "Staffordshire Bull Terrier",
  },
  32: {
    "facts": [
      " Small, elegant dogs with a distinctive oriental appearance.",
      " Friendly and gentle temperament.",
      " Entertaining antics and may form strong bonds."
      ],
    "prediction": "Japanese Chin",
  },
  33: {
    "facts": [
      " Giant dogs with a gentle and friendly disposition.",
      " Often good with children and calm indoors.",
      " Require regular grooming and may drool due to loose jowls."
      ],
    "prediction": "Saint Bernard",
  },
  34: {
    "facts": [
      " Medium to large-sized dogs with a strong, muscular build.",
      " Friendly, intelligent, and protective.",
      " Regular exercise is crucial for maintaining physical health."
      ],
    "prediction": "Boxer",
  },
  35: {
    "facts": [
      " Large and powerful dogs with a gentle and sweet nature.",
      " Excellent swimmers, used in water rescue work.",
      " Good with children, patient demeanor."
      ],
    "prediction": "Newfoundland",
  },
  36: {
    "facts": [
      " Medium-sized dogs with a soft, wheaten-colored coat.",
      " Playful nature, good with children and other pets.",
      " Regular grooming required."
      ],
    "prediction": "Wheaten Terrier",
  },
};

# %%
from flask import Flask, render_template
from flask_ngrok import run_with_ngrok
from flask import jsonify, request
from flask_cors import CORS

app = Flask(__name__)
CORS(app)
run_with_ngrok(app)

@app.route("/")
def hello():
  data = {
      "title": "Animal Chatter: Cat and Dog breed prediction"
  }

  return render_template('index.html', **data)

@app.route("/api/v1/predict", methods=["POST"])
def predict_breed():
  # check if the request sent over an imag

  if 'image' in request.files:
    req_image = request.files['image']
    req_image.save(req_image.filename)
    image = tf.keras.utils.load_img(f"/content/{req_image.filename}",target_size=(180,180))
    image = tf.keras.utils.img_to_array(image)
    image = image/255.0
    prediction_image=np.array(image)
    prediction_image= np.expand_dims(image, axis=0)
    weight_array = new_model.predict(prediction_image)
    score = tf.nn.softmax(weight_array[0])
    prediction_conf = 100 * np.max(score)
    class_type = np.argmax(score)
    print(prediction_conf)

    response = reverse_mapping[class_type]
    print(response)
  else:
    response = {
        "status": "failed"
    }

  return jsonify(response)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://025f-35-202-18-247.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [07/Dec/2023 22:54:57] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Dec/2023 22:54:57] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [07/Dec/2023 22:54:57] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 [==============================] - 0s 76ms/step
# INFO:werkzeug:127.0.0.1 - - [07/Dec/2023 22:55:06] "POST /api/v1/predict HTTP/1.1" 200 -
# 7.015844434499741
# {'facts': [' Compact size, wrinkled face, and curled tail.', ' Playful and sociable nature, suitable for various households.', ' Prone to weight gain, sensitive to extreme temperatures.'], 'prediction': 'Pug'}
